# %%
# !where pip
# Out:
# D:\Personal\self study\uber fare prediction\development\virtualenv_dev_uber_fare\Scripts\pip.exe
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Scripts\pip.exe

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# alembic                            1.13.2
# aniso8601                          9.0.1
# blinker                            1.8.2
# cachetools                         5.5.0
# certifi                            2024.7.4
# charset-normalizer                 3.3.2
# click                              8.1.7
# cloudpickle                        3.0.0
# colorama                           0.4.6
# contourpy                          1.2.1
# cycler                             0.12.1
# databricks-sdk                     0.30.0
# Deprecated                         1.2.14
# docker                             7.1.0
# entrypoints                        0.4
# Flask                              3.0.3
# fonttools                          4.53.1
# gitdb                              4.0.11
# GitPython                          3.1.43
# google-auth                        2.34.0
# graphene                           3.3
# graphql-core                       3.2.3
# graphql-relay                      3.2.0
# greenlet                           3.0.3
# idna                               3.7
# importlib_metadata                 7.2.1
# itsdangerous                       2.2.0
# Jinja2                             3.1.4
# joblib                             1.4.2
# kiwisolver                         1.4.5
# Mako                               1.3.5
# Markdown                           3.7
# MarkupSafe                         2.1.5
# matplotlib                         3.9.2
# mlflow                             2.15.1
# mlflow-skinny                      2.15.1
# numpy                              1.26.4
# opentelemetry-api                  1.26.0
# opentelemetry-sdk                  1.26.0
# opentelemetry-semantic-conventions 0.47b0
# packaging                          24.1
# pandas                             2.2.2
# pillow                             10.4.0
# pip                                24.1.2
# protobuf                           5.27.3
# pyarrow                            15.0.2
# pyasn1                             0.6.0
# pyasn1_modules                     0.4.0
# pyparsing                          3.1.2
# python-dateutil                    2.9.0.post0
# pytz                               2024.1
# pywin32                            306
# PyYAML                             6.0.2
# querystring-parser                 1.2.4
# requests                           2.32.3
# rsa                                4.9
# scikit-learn                       1.5.1
# scipy                              1.14.1
# six                                1.16.0
# smmap                              5.0.1
# SQLAlchemy                         2.0.32
# sqlparse                           0.5.1
# threadpoolctl                      3.5.0
# typing_extensions                  4.12.2
# tzdata                             2024.1
# urllib3                            2.2.2
# waitress                           3.0.0
# Werkzeug                           3.0.3
# wrapt                              1.16.0
# xgboost                            2.1.1
# zipp                               3.20.0

# %%
import pandas as pd
import numpy as np
import mlflow
from math import radians, sin, cos, sqrt, atan2
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_csv('../uber.csv')

# %%
df.drop(columns = ['Unnamed: 0','key'], inplace = True)

# %%
df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
f'Number of rows: {df.shape[0]:,}'
# Out:
# 'Number of rows: 200,000'

# %% [markdown]
# ### Datetime feature engineering

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime)

# %%
df['dayofyear'] = df.pickup_datetime.dt.dayofyear
df['dayofweek'] = df.pickup_datetime.dt.weekday
df['time'] = df.pickup_datetime.dt.time

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  dayofyear  dayofweek  \
# 0         -73.999512         40.723217                1        127          3
# 1         -73.994710         40.750325                1        198          4
# 2         -73.962565         40.772647                1        236          0
# 3         -73.965316         40.803349                3        177          4
# 4         -73.973082         40.761247                5        240          3
#
#        time
# 0  19:52:06
# 1  20:04:56
# 2  21:45:00
# 3  08:22:21
# 4  17:47:00

# %% [markdown]
# **Checking Consistency**

# %%
np.sort(df.time.unique())
# Out:
# array([datetime.time(0, 0), datetime.time(0, 0, 2),
#        datetime.time(0, 0, 3), ..., datetime.time(23, 59, 57),
#        datetime.time(23, 59, 58), datetime.time(23, 59, 59)], dtype=object)

# %%
df.dayofweek.nunique()
# Out:
# 7

# %%
df.dayofyear.nunique()
# Out:
# 366

# %% [markdown]
# **It seems that all datetime features are consistant and that all possible values are available**

# %% [markdown]
# ### Transforming location features and summerize them to be only distance

# %% [markdown]
# Here for simplicity, instead of using an API to get the exact street distance between the 2 locations, I'll use Haversine distance

# %%
def haversine_distance(long1,lat1, long2, lat2):    
    # Convert latitude and longitude to radians
    lat1_rad = radians(lat1)
    long1_rad = radians(long1)
    lat2_rad = radians(lat2)
    long2_rad = radians(long2)

    # Haversine formula
    dlong = long2_rad - long1_rad
    dlat = lat2_rad - lat1_rad
    a = sin(dlat/2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlong/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = 6371 * c  # Earth radius in kilometers
    return distance

# %%
df['distance_km'] = df.apply(lambda x: haversine_distance(x.pickup_longitude, x.pickup_latitude, x.dropoff_longitude, x.dropoff_latitude) ,axis = 1 )

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  dayofyear  dayofweek  \
# 0         -73.999512         40.723217                1        127          3
# 1         -73.994710         40.750325                1        198          4
# 2         -73.962565         40.772647                1        236          0
# 3         -73.965316         40.803349                3        177          4
# 4         -73.973082         40.761247                5        240          3
#
#        time  distance_km
# 0  19:52:06     1.683323
# 1  20:04:56     2.457590
# 2  21:45:00     5.036377
# 3  08:22:21     1.661683
# 4  17:47:00     4.475450

# %% [markdown]
# Lets see the fare amount and distance overtime

# %%
df.groupby(df.pickup_datetime.dt.year)[['fare_amount','distance_km']].median()
# Out:
#                  fare_amount  distance_km
# pickup_datetime
# 2009                     7.7     2.063706
# 2010                     7.7     2.095978
# 2011                     7.7     2.110952
# 2012                     8.5     2.166306
# 2013                     9.5     2.153051
# 2014                     9.5     2.146175
# 2015                     9.5     2.100351

# %% [markdown]
# **As seen above, the year didn't really make that difference, so I'll discard the idea of adding the gas price or some feature reflects the inflation just for simplicity**

# %%
df.drop(columns = ['pickup_datetime','pickup_longitude','pickup_latitude','dropoff_longitude', 'dropoff_latitude' ], inplace = True)

# %%
df.head()
# Out:
#    fare_amount  passenger_count  dayofyear  dayofweek      time  distance_km
# 0          7.5                1        127          3  19:52:06     1.683323
# 1          7.7                1        198          4  20:04:56     2.457590
# 2         12.9                1        236          0  21:45:00     5.036377
# 3          5.3                3        177          4  08:22:21     1.661683
# 4         16.0                5        240          3  17:47:00     4.475450

# %% [markdown]
# ### Checking other features

# %%
df.passenger_count.value_counts()
# Out:
# passenger_count
# 1      138425
# 2       29428
# 5       14009
# 3        8881
# 4        4276
# 6        4271
# 0         709
# 208         1
# Name: count, dtype: int64

# %% [markdown]
# I'll simply drop any row with passanger count greater than 6 or equal to 0

# %%
df = df[(df['passenger_count'] <= 6) & (df['passenger_count'] >= 1)]

# %%
f'{df.shape[0]:,}'
# Out:
# '199,290'

# %% [markdown]
# Now that all features are ready, I'll start transforming

# %% [markdown]
# ### Feature Transformation

# %%
df['dayofyear_sin'] = np.sin(2*np.pi*df['dayofyear']/366)
df['dayofyear_cos'] = np.cos(2*np.pi*df['dayofyear']/366)
df['dayofweek_sin'] = np.sin(2*np.pi*df['dayofweek']/6)
df['dayofweek_cos'] = np.cos(2*np.pi*df['dayofweek']/6)
df['total_seconds'] = df['time'].apply(lambda t: t.hour * 3600 + t.minute * 60 + t.second )
df['time_sin'] = np.sin(2*np.pi*df['total_seconds']/86400)
df['time_cos'] = np.cos(2*np.pi*df['total_seconds']/86400)

# %%
df.head()
# Out:
#    fare_amount  passenger_count  dayofyear  dayofweek      time  distance_km  \
# 0          7.5                1        127          3  19:52:06     1.683323
# 1          7.7                1        198          4  20:04:56     2.457590
# 2         12.9                1        236          0  21:45:00     5.036377
# 3          5.3                3        177          4  08:22:21     1.661683
# 4         16.0                5        240          3  17:47:00     4.475450
#
#    dayofyear_sin  dayofyear_cos  dayofweek_sin  dayofweek_cos  total_seconds  \
# 0       0.819972      -0.572404   1.224647e-16           -1.0          71526
# 1      -0.254671      -0.967028  -8.660254e-01           -0.5          72296
# 2      -0.789418      -0.613856   0.000000e+00            1.0          78300
# 3       0.102821      -0.994700  -8.660254e-01           -0.5          30141
# 4      -0.829677      -0.558244   1.224647e-16           -1.0          64020
#
#    time_sin  time_cos
# 0 -0.882743  0.469857
# 1 -0.855063  0.518525
# 2 -0.555570  0.831470
# 3  0.813228 -0.581946
# 4 -0.998392 -0.056693

# %%
final_df = df.drop(columns = ['dayofyear','dayofweek','time','total_seconds']).reset_index(drop = True)

# %%
final_df.head()
# Out:
#    fare_amount  passenger_count  distance_km  dayofyear_sin  dayofyear_cos  \
# 0          7.5                1     1.683323       0.819972      -0.572404
# 1          7.7                1     2.457590      -0.254671      -0.967028
# 2         12.9                1     5.036377      -0.789418      -0.613856
# 3          5.3                3     1.661683       0.102821      -0.994700
# 4         16.0                5     4.475450      -0.829677      -0.558244
#
#    dayofweek_sin  dayofweek_cos  time_sin  time_cos
# 0   1.224647e-16           -1.0 -0.882743  0.469857
# 1  -8.660254e-01           -0.5 -0.855063  0.518525
# 2   0.000000e+00            1.0 -0.555570  0.831470
# 3  -8.660254e-01           -0.5  0.813228 -0.581946
# 4   1.224647e-16           -1.0 -0.998392 -0.056693

# %% [markdown]
# **Now that we have the features store ready lets do some ML experiments**

# %% [markdown]
# # Modeling

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc_uber_fare")
# Out:
# 2024/08/21 16:38:09 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/08/21 16:38:09 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# INFO  [alembic.runtime.migration] Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# INFO  [alembic.runtime.migration] Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# INFO  [alembic.runtime.migration] Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2024/08/21 16:38:10 INFO mlflow.tracking.fluent: Experiment with name 'nyc_uber_fare' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///D:/Personal/self study/uber fare prediction/development/mlruns/1', creation_time=1724247490097, experiment_id='1', last_update_time=1724247490097, lifecycle_stage='active', name='nyc_uber_fare', tags={}>

# %%
X = final_df.drop(['fare_amount'], axis = 1).reset_index(drop = True)
y = final_df['fare_amount']

# %%
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
import xgboost

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pickle
os.makedirs("models", exist_ok=True)

# %% [markdown]
# Trying a run with the default params of xgboost

# %%
with mlflow.start_run():
    mlflow.set_tag("model_type", "xgboost")
    mlflow.set_tag('developer', 'Marwan Yasser')
    xgb_r = xgboost.XGBRegressor()
    xgb_r.fit(X_train, y_train)
    pred = xgb_r.predict(X_test) 
    rmse = MSE(y_test, pred, squared = False)
    print('rmse: ', rmse)
    mlflow.log_metric("rmse",rmse)

    with open("models/xgb_r.bin", "wb") as f:
        pickle.dump(xgb_r, f)
    mlflow.log_artifact(local_path="models/xgb_r.bin", artifact_path="models_pickle")
# Out:
# rmse:  5.399106777604885

# %%
pred = xgb_r.predict(X_train)
train_rmse = MSE(y_train,pred, squared =False)
pred = xgb_r.predict(X_test) 
test_rmse = MSE(y_test, pred, squared = False)
print('train loss: ', train_rmse, ',  Test loss: ', test_rmse)
# Out:
# train loss:  4.319850361794423 ,  Test loss:  5.399106777604885

# %% [markdown]
# Use random search to tune the hyperparameters of xgboost

# %%
param_dist = {
    'n_estimators': [100, 200, 300],           # Number of boosting rounds
    'max_depth': [3, 4, 5, 6, 7, 8, 9],              # Maximum depth of a tree
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],        # Step size shrinkage
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],              # Fraction of samples used per tree
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],       # Fraction of features used per tree
    'min_child_weight': [1, 3, 5, 7],                    # Minimum sum of instance weight (Hessian)
    'gamma': [0, 0.1, 0.2, 0.3, 0.4],                    # Minimum loss reduction required for a split
    'reg_alpha': [0, 0.01, 0.1, 1, 10],                  # L1 regularization term on weights
    'reg_lambda': [0, 0.01, 0.1, 1, 10],                 # L2 regularization term on weights
}

# %%
with mlflow.start_run():
    mlflow.set_tag("model_type", "xgboost")
    mlflow.set_tag('developer', 'Marwan Yasser')
    xgb_r = xgboost.XGBRegressor( tree_method="gpu_hist")
    # Initialize RandomizedSearchCV
    random_search = RandomizedSearchCV(
        estimator=xgb_r, 
        param_distributions=param_dist, 
        n_iter=150,          # Number of parameter settings that are sampled
        cv=5,                # 5-fold cross-validation
        verbose=2,           # Display progress messages
        random_state=42,     # For reproducibility
    )
    
    random_search.fit(X_train, y_train)
    
    best_params = random_search.best_params_
    print("Best Parameters found by RandomizedSearchCV:")
    print(best_params)
    mlflow.log_params(best_params)
    best_model_xgb= random_search.best_estimator_
    
    pred = best_model_xgb.predict(X_train)
    train_rmse = MSE(y_train,pred, squared =False)
    
    pred = best_model_xgb.predict(X_test) 
    test_rmse = MSE(y_test, pred, squared = False)
    print('Train loss: ', train_rmse, ', Test loss: ', test_rmse)
    mlflow.log_metric('rmse', test_rmse)

    with open("models/xgb_r_tuned.bin", "wb") as f:
        pickle.dump(best_model_xgb, f)
    mlflow.log_artifact(local_path="models/xgb_r_tuned.bin", artifact_path="models_pickle")
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   4.0s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   4.0s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.3, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.6; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=10, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.3, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=8, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=8, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=8, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=8, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.3, max_depth=8, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   1.9s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=10, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=10, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=10, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=10, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=10, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.01, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   4.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=10, reg_lambda=0.01, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=300, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.05, max_depth=8, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1, subsample=0.9; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=5, n_estimators=300, reg_alpha=0.1, reg_lambda=0.01, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=0, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   2.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   2.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=0.1, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=7, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=100, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.3, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=300, reg_alpha=1, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=300, reg_alpha=1, reg_lambda=0.01, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=300, reg_alpha=1, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=300, reg_alpha=1, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=300, reg_alpha=1, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.4, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=1, reg_lambda=0.01, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=300, reg_alpha=10, reg_lambda=1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.9; total time=   2.0s
# ...
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=1, n_estimators=100, reg_alpha=10, reg_lambda=1, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=0.1, subsample=0.9; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=0.1, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=0.1, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=0.1, subsample=0.9; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=0.1, subsample=0.9; total time=   2.8s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=1, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=200, reg_alpha=10, reg_lambda=10, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=0, subsample=1.0; total time=   3.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=10, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=10, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=10, subsample=0.9; total time=   1.5s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=10, subsample=0.9; total time=   1.3s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=10, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, n_estimators=300, reg_alpha=10, reg_lambda=0.1, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.2, max_depth=7, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=1, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.01, max_depth=6, min_child_weight=7, n_estimators=300, reg_alpha=10, reg_lambda=0, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.1, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=200, reg_alpha=10, reg_lambda=0.1, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=100, reg_alpha=10, reg_lambda=0.1, subsample=1.0; total time=   0.6s
# Best Parameters found by RandomizedSearchCV:
# {'subsample': 0.9, 'reg_lambda': 0.1, 'reg_alpha': 0.01, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 3, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.7}
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[42], line 23
#      20 mlflow.log_params(best_params)
#      21 best_model_xgb= random_search.best_estimator_
# ---> 23 pred = xgb_r.predict(X_train)
#      24 train_rmse = MSE(y_train,pred, squared =False)
#      26 pred = best_model_xgb.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:805, in XGBModel.get_booster(self)
#     802 if not self.__sklearn_is_fitted__():
#     803     from sklearn.exceptions import NotFittedError
# --> 805     raise NotFittedError("need to call fit or load_model beforehand")
#     806 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand

# %%
with mlflow.start_run():
    mlflow.set_tag("model_type", "xgboost")
    mlflow.set_tag('developer', 'Marwan Yasser')
    
    pred = best_model_xgb.predict(X_test) 
    test_rmse = MSE(y_test, pred, squared = False)
    print('Train loss: ', train_rmse, ', Test loss: ', test_rmse)
    mlflow.log_metric('rmse', test_rmse)
    mlflow.log_params(best_params)
    with open("models/xgb_r_tuned.bin", "wb") as f:
        pickle.dump(best_model_xgb, f)
    mlflow.log_artifact(local_path="models/xgb_r_tuned.bin", artifact_path="models_pickle")
# Out:
# Train loss:  5.506313232133612 , Test loss:  5.215810195970013

# %% [markdown]
# I'll just stop here for simplicity
